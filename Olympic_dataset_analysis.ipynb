# %% [markdown]
# ## Olympic Data  Set

# %% [markdown]
# ### DESCRIPTION:
#
# #### This is a historical dataset on the modern Olympic Games, including all the Games from Athens 1896 to Rio 2016.
# #### The file athlete_events.csv contains 271116 rows and 15 columns. Each row corresponds to an individual athlete competing in an individual Olympic event (athlete-events).
# The columns are:
# 1.ID - Unique number for each athlete
#
# 2.Name - Athlete's name
#
# 3.Sex - M or F
#
# 4.Age - Integer
#
# 5.Height - In centimeters
#
# 6.Weight - In kilograms
#
# 7.Team - Team name
#
# 8.Games - Year and season
#
# 9.Year - Integer
#
# 10.Season - Summer or Winter
#
# 11.City - Host city
#
# 12.Sport - Sport
#
# 13.Event - Event
#
# 14.Medal - Gold, Silver, Bronze, or NA

# %% [markdown]
# ### -Reading From csv file

# %%
import numpy as np
import pandas as pd
a=pd.read_csv('athlete_events.csv')
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %% [markdown]
# ### 1.PARTICIPATION OF ATHLETES IN OLYMPICS(1896-2016)
#            - Gives the name of athletes along with the count of their participation.

# %%
pr=a['Name'].value_counts() 
pr.head(30)
# Out:
# Robert Tait McKenzie                     58
# Heikki Ilmari Savolainen                 39
# Joseph "Josy" Stoffel                    38
# Ioannis Theofilakis                      36
# Takashi Ono                              33
# Alfrd (Arnold-) Hajs (Guttmann-)         32
# Jean Lucien Nicolas Jacoby               32
# Alexandros Theofilakis                   32
# Andreas Wecker                           32
# Michel Mathiot                           31
# Alfred James Munnings                    31
# Alfred August "Al" Jochim                31
# Johann "Hans" Sauter                     31
# Michael Fred Phelps, II                  30
# Yordan Yovchev Yovchev                   30
# Karl Tore William Thoresson              30
# Oksana Aleksandrovna Chusovitina         29
# Ivan Joseph Martin Osiier                29
# Miltiades Manno                          28
# Adrianus Egbert Willem "Arie" de Jong    27
# Ole Einar Bjrndalen                      27
# ...

# %% [markdown]
# ### 2.COUNT OF PARTICIPATION
#              -gives the count of total participation in olympics.

# %%
a['ID'].count()
# Out:
# 271116

# %% [markdown]
# ### 3.NAMES OF ATHLETES WHO SCORED GOLD MEDALS
#             -lists out the names of athletes who won gold medal overall.

# %%
b=a.Medal=="Gold"
k=a[b].Name
k.head(20)
# Out:
# 3                  Edgar Lindenau Aabye
# 42              Paavo Johannes Aaltonen
# 44              Paavo Johannes Aaltonen
# 48              Paavo Johannes Aaltonen
# 60                   Kjetil Andr Aamodt
# 73                   Kjetil Andr Aamodt
# 76                   Kjetil Andr Aamodt
# 78                   Kjetil Andr Aamodt
# 79            Ragnhild Margrethe Aamodt
# 113                     Roald Edgar Aas
# 117                 Thomas Valentin Aas
# 150                          Ren Abadie
# 172    Aleksey Aleksandrovich Abalmasov
# 173                           Luc Abalo
# 174                           Luc Abalo
# 178          Jouan Patrice Abanda Etong
# 182              Jos Mara Abarca Plotas
# 188             Alejandro Abascal Garca
# 200                      Jol Marc Abati
# 218                  Agostino Abbagnale
# Name: Name, dtype: object

# %% [markdown]
# ### 4.Data of athletes who won gold medal in India
#             -details of indians who won gold medal.

# %%
c=a.Medal=="Gold"
d=a.Team=="India"
e=c & d
a[e]
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 4732      2699                      Shaukat Ali   M  30.0     NaN     NaN
# 4736      2703                 Syed Mushtaq Ali   M  22.0   165.0    61.0
# 5032      2864              Richard James Allen   M  25.0   172.0     NaN
# 5033      2864              Richard James Allen   M  30.0   172.0     NaN
# 5034      2864              Richard James Allen   M  34.0   172.0     NaN
# 10274     5618            Sardar Mohammad Aslam   M   NaN     NaN     NaN
# 21208    11197              Vasudevan Bhaskaran   M  29.0   174.0    68.0
# 22004    11601                   Abhinav Bindra   M  25.0   173.0    70.0
# 24657    12911              Lal Shah S. Bokhari   M  23.0   173.0     NaN
# 29022    15011  Frank Gerald Singlehurst Brewin   M  22.0     NaN     NaN
# 35960    18475       Richard John "Dickie" Carr   M  21.0   180.0     NaN
# 38352    19716                 Dhyan Chand Bais   M  22.0   169.0     NaN
# ...

# %% [markdown]
# ### 5.Count of Medals won between 1896-2016 by each team
#           -lists count of all medals won by each team.

# %%
ct=pd.crosstab(a.Team, a.Medal,margins=True)
ct.head(20)
# Out:
# Medal                         Bronze  Gold  Silver   All
# Team
# A North American Team              4     0       0     4
# Afghanistan                        2     0       0     2
# Algeria                            8     5       4    17
# Ali-Baba II                        5     0       0     5
# Amateur Athletic Association       0     5       0     5
# Amstel Amsterdam                   4     0       0     4
# Ancora                             0     4       0     4
# Angelita                           0    12       0    12
# Antwerpia V                        5     0       0     5
# Aphrodite                          3     0       0     3
# Argentina                         91    91      84   266
# Argonaut Rowing Club               6     0       0     6
# Armenia                            9     2       5    16
# Aschenbrodel                       0     4       4     8
# Atalanta Boat Club-1               0     2       0     2
# ...

# %% [markdown]
# ### 6.Top 5 Teams in Olympic Achievements
#             -lists 5 top teams in olympics history.

# %%
ct1=ct.sort_values(by=['All'],ascending=False)

ct1.head(6)
# Out:
# Medal          Bronze   Gold  Silver    All
# Team
# All             13295  13372   13116  39783
# United States    1233   2474    1512   5219
# Soviet Union      677   1058     716   2451
# Germany           678    679     627   1984
# Great Britain     572    519     582   1673
# France            577    455     518   1550

# %% [markdown]
# ### 7. Most played sport in olympics
#           -gives the count of sport which is played the most in olympics.

# %%
ct6=a.groupby('Sport').Sport.count()
ct6.head(25)
# Out:
# Sport
# Aeronautics                 1
# Alpine Skiing            8829
# Alpinism                   25
# Archery                  2334
# Art Competitions         3578
# Athletics               38624
# Badminton                1457
# Baseball                  894
# Basketball               4536
# Basque Pelota               2
# Beach Volleyball          564
# Biathlon                 4893
# Bobsleigh                3058
# Boxing                   6047
# Canoeing                 6171
# Cricket                    24
# Croquet                    19
# Cross Country Skiing     9133
# Curling                   463
# Cycling                 10859
# Diving                   2842
# Equestrianism            6344
# Fencing                 10735
# Figure Skating           2298
# Football                 6745
# Name: Sport, dtype: int64

# %%
ct6.max()
# Out:
# 38624

# %%
a['Sport'].value_counts().idxmax()
# Out:
# 'Athletics'

# %% [markdown]
# ### 8.Female and Male participation
#          -gives the number of male and female participation.

# %%
ct10=a.groupby('Sex').Sex.count()
ct10
# Out:
# Sex
# F     74522
# M    196594
# Name: Sex, dtype: int64

# %% [markdown]
# ### 9. Plot on Gender
#           -a plot on sex v/s age which shows male and female participation
#            based on their age.

# %%
import matplotlib.pyplot as plt
a.groupby(['Sex'])['Age'].nunique().plot(kind='bar',stacked=True)

# %% [markdown]
# ### 10. Pie Plot on Medals won
#           -a pie plot on how many silver,gold,bronze medals won in total analysis.

# %%
import matplotlib.pyplot as plt
import numpy as np
size=np.array(a.groupby("Medal").size())
labels="Gold","Silver","Bronze"
colors=["red","purple","yellow"]
explode=(0.05,0.05,0.05)
plt.pie(size,explode=explode,labels=labels,colors=colors,shadow="True",autopct="%.f%%")
plt.show()

# %% [markdown]
# ### 11.Histogram on height and weight
#          -a height v/s weight categorization.

# %%
plt.hist(a.Height,color='red')
plt.hist(a.Weight,color='purple')
#plt.hist(a.,color='red',bins=20)
plt.show()

# %% [markdown]
# ### 12. Bar Graph on Year v/s Age
#               - a plot on Age v/s year which shows in each year approximately
#                 what was the age of athletes participating.

# %%
a.groupby('Year')['Age'].nunique().plot(kind='bar')
fig = plt.figure(figsize=(18,20))
plt.show()

# %% [markdown]
# ### 13. Scatter plot
#            -plot on ID v/s Age which shows the number of athlete participation based on their age

# %%
plt.scatter(a.ID,a.Age,marker='^',c=c)
plt.show()

# %% [markdown]
# ### 14. Line graph
#           -a graph which shows the participation of athlete based on year.

# %%
# %matplotlib inline
a.groupby('Year')['ID'].nunique().plot(kind='line',style='.--',color='green')
plt.show()

# %% [markdown]
# ### 15. Most participation
#         -returns name of athlete with maximum participation.

# %%
a['Name'].value_counts().idxmax()
# Out:
# 'Robert Tait McKenzie'

# %%
import seaborn as sns
sns.pairplot(a.loc[:,a.dtypes == 'float64'])
# Out:
# C:\pythonfile\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\pythonfile\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
from matplotlib.ticker import AutoMinorLocator
fig = plt.figure(figsize=(18,6))
filtered_years = a[a['Year'] >2000]
ax1 = sns.violinplot('Year',"Age", data=filtered_years,color='red')
ax1.minorticks_on()
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)
# Out:
# C:\pythonfile\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
class1 = a[a['Height']>190]
sns.lmplot("Height", "Weight", data=class1, fit_reg=False, col='Age', col_wrap=2)

# %%
sns.kdeplot(a.Height,a.Weight,kind='hex')
# Out:
# C:\pythonfile\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# C:\pythonfile\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)

# %%
filtered_years1 = a[a['Sex'] =='F'] 
sns.catplot(x='Sex', y='Year', data=filtered_years1, col='Sex', kind='boxen')
